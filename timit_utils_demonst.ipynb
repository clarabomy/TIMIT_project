# %%
# %load_ext autoreload
# %autoreload 2

import timit_utils as tu
import timit_utils.audio_utils as au
import timit_utils.drawing_utils as du
# %matplotlib inline

# %% [markdown]
# # Corpus:
# Load the TIMIT database into a Corpus. All it does is contain two sub-corpuses, for train and test sets.

# %%
corpus = tu.Corpus('TIMIT')
train = corpus.train
corpus.train, corpus.test
# Out:
# (<timit_utils.core.SubCorpus at 0x21fb6e36cf8>,
#  <timit_utils.core.SubCorpus at 0x21fb6e36f60>)

# %% [markdown]
# ... basically, that's it. Everything below is convenient ways to load audio and transcription data.

# %% [markdown]
# # Display sentence audio, word, and phoneme transcriptions

# %%
sentence = train.sentences_by_phone_df('aa').sentence[0]
print(f'Sentence {sentence.name}, sample rate: {sentence.sample_rate}')
du.DrawVerticalPanels([du.AudioPanel(sentence.raw_audio, show_x_axis=True), 
                       du.WordsPanel(sentence.words_df, sentence.raw_audio.shape[0], show_x_axis=True),
                       du.PhonesPanel(sentence.phones_df, sentence.raw_audio.shape[0])
                      ])
# Out:
# Sentence SA1, sample rate: 16000

# %% [markdown]
# # SubCorpus
# Examine the train SubCorpus in various ways:

# %% [markdown]
# ## Get a dataframe containing word counts spoken by all people.

# %%
train.words_to_usages_df.head(20)
# Out:
#           'em  a  abbreviate  abides  ability  able  ably  abolish  aborigine  \
# ABC0 (M)    0  2           0       0        0     0     0        1          0
# ADC0 (M)    0  3           0       0        0     0     0        0          0
# ADD0 (M)    0  1           0       0        0     0     0        0          0
# AEB0 (M)    0  1           0       0        0     0     0        0          0
# AEM0 (F)    0  3           0       0        0     0     0        0          0
# AEO0 (M)    0  2           0       0        0     0     0        0          0
# AFM0 (M)    0  2           0       0        0     0     0        0          0
# AJP0 (M)    0  4           0       0        0     0     0        0          0
# AJW0 (F)    0  2           0       0        0     0     0        0          0
# AKB0 (M)    2  0           0       0        0     0     0        0          0
# AKR0 (M)    0  2           0       0        0     0     0        0          0
# ALK0 (F)    0  1           0       0        0     0     0        0          0
# ALR0 (F)    0  1           0       0        0     0     0        0          0
# APB0 (F)    0  0           0       0        0     0     0        0          0
# APV0 (M)    0  3           0       0        0     0     0        0          0
# ARC0 (M)    0  2           0       0        0     0     0        0          0
# ARW0 (M)    0  3           0       0        0     0     0        0          0
# BAR0 (M)    0  5           0       0        0     0     0        0          0
# BAS0 (F)    0  4           0       0        0     0     0        0          0
# BBR0 (M)    0  1           0       0        0     0     0        0          0
#
#           aborigines  ...   zebras  zig  zinnias  zippers  zircons  zombie  \
# ABC0 (M)           0  ...        0    0        0        0        0       0
# ADC0 (M)           0  ...        0    0        0        0        0       0
# ADD0 (M)           0  ...        0    0        0        0        0       0
# AEB0 (M)           0  ...        0    0        0        0        0       0
# AEM0 (F)           0  ...        0    0        0        0        0       0
# AEO0 (M)           0  ...        0    1        0        0        0       0
# AFM0 (M)           0  ...        0    0        0        0        0       0
# AJP0 (M)           0  ...        0    0        0        0        0       0
# AJW0 (F)           0  ...        0    0        0        0        0       0
# AKB0 (M)           0  ...        0    0        0        0        0       0
# AKR0 (M)           0  ...        0    0        0        0        0       0
# ALK0 (F)           0  ...        0    0        0        0        0       0
# ALR0 (F)           0  ...        0    0        0        0        0       0
# APB0 (F)           0  ...        0    0        0        0        0       0
# APV0 (M)           0  ...        0    0        0        0        0       0
# ARC0 (M)           0  ...        0    0        0        0        0       0
# ARW0 (M)           0  ...        0    0        0        0        0       0
# BAR0 (M)           0  ...        0    0        0        0        0       0
# BAS0 (F)           0  ...        0    0        0        0        0       0
# BBR0 (M)           0  ...        0    0        0        0        0       0
#
#           zones  zoo  zoologist  zoos
# ABC0 (M)      0    0          0     0
# ADC0 (M)      0    0          0     0
# ADD0 (M)      0    0          0     0
# AEB0 (M)      0    0          0     0
# AEM0 (F)      0    0          0     0
# AEO0 (M)      0    0          0     0
# AFM0 (M)      0    0          0     0
# AJP0 (M)      0    0          0     0
# AJW0 (F)      0    0          0     0
# AKB0 (M)      0    0          0     0
# AKR0 (M)      0    0          0     0
# ALK0 (F)      0    0          0     0
# ALR0 (F)      0    0          0     0
# APB0 (F)      0    0          0     0
# APV0 (M)      0    0          0     0
# ARC0 (M)      0    0          0     0
# ARW0 (M)      0    0          0     0
# BAR0 (M)      0    0          0     0
# BAS0 (F)      0    0          0     0
# BBR0 (M)      0    0          0     0
#
# [20 rows x 4893 columns]

# %% [markdown]
# ... user ABC0, a Male, spoke the word 'a' twice...

# %% [markdown]
# ## Get a dataframe containing phoneme counts spoken by all people.

# %%
train.phones_to_usages_df.head(3)
# Out:
#           aa  ae  ah  ao  aw  ax  ax-h  axr  ay  b ...  tcl  th  uh  uw  ux  \
# ABC0 (M)   8  12   3   4   1   1     2   10   1  6 ...   10   1   2   0   7
# ADC0 (M)   6  11   6   7   1   6     1    1   7  7 ...   13   1   1   0   6
# ADD0 (M)   7  11   3   8   2   2     1    2   5  7 ...   18   1   0   2   8
#
#           v  w  y   z  zh
# ABC0 (M)  7  5  4  12   1
# ADC0 (M)  6  6  4   8   0
# ADD0 (M)  4  8  5   6   0
#
# [3 rows x 60 columns]

# %% [markdown]
# ## Given any word, get a dataframe containing all the people who have said that word, the corresponding sentences, and counts within that sentence.

# %%
train.sentences_by_word_df('green')
# Out:
#          sentence count
# BMA0 (M)    SX412     1
# FER0 (M)    SX412     1
# FMC0 (M)    SX412     1
# JDG0 (M)    SX412     1
# JDM2 (F)    SX412     1
# RTJ0 (M)    SX412     1
# SDC0 (F)    SX412     1

# %% [markdown]
# ## Same for phonemes

# %%
train.sentences_by_phone_df('aa')
# Out:
#          sentence count
# ABC0 (M)      SA1     2
# ABC0 (M)   SI1620     1
# ABC0 (M)   SI2041     1
# ABC0 (M)    SI781     1
# ABC0 (M)    SX331     1
# ABC0 (M)    SX421     1
# ABC0 (M)     SX61     1
# ADC0 (M)      SA1     1
# ADC0 (M)    SI737     1
# ADC0 (M)    SX107     1
# ADC0 (M)     SX17     1
# ADC0 (M)    SX287     1
# ADC0 (M)    SX377     1
# ADD0 (M)      SA1     1
# ADD0 (M)    SX178     2
# ADD0 (M)    SX268     1
# ADD0 (M)    SX358     1
# ADD0 (M)    SX448     1
# ADD0 (M)     SX88     1
# AEB0 (M)      SA1     1
# AEB0 (M)   SI1411     2
# AEB0 (M)    SI990     3
# AEB0 (M)    SX180     1
# AEB0 (M)    SX270     2
# AEM0 (F)      SA1     1
# AEM0 (F)   SI1392     1
# AEM0 (F)    SX222     1
# AEM0 (F)    SX402     1
# AEM0 (F)     SX42     2
# AEO0 (M)      SA1     2
# ...           ...   ...
# WGR0 (M)      SA1     2
# WGR0 (M)   SI1606     1
# WGR0 (M)   SI2236     1
# WGR0 (M)    SI976     1
# WGR0 (M)    SX256     2
# WGR0 (M)     SX76     1
# WRE0 (M)      SA1     2
# WRE0 (M)   SI1057     1
# WRE0 (M)   SI2317     1
# WRE0 (M)    SX337     2
# WRE0 (M)    SX427     1
# WRP0 (M)      SA1     2
# WRP0 (M)   SI1443     2
# WRP0 (M)   SI1525     2
# WRP0 (M)    SX363     1
# WSB0 (M)      SA1     3
# WSB0 (M)    SI996     1
# WSB0 (M)    SX186     2
# WSB0 (M)    SX276     2
# WSB0 (M)    SX366     2
# WSB0 (M)      SX6     1
# WSB0 (M)     SX96     1
# WSH0 (M)      SA1     2
# WSH0 (M)    SI796     1
# WSH0 (M)    SX166     2
# WSH0 (M)    SX256     3
# WSH0 (M)     SX76     1
# ZMB0 (M)      SA1     1
# ZMB0 (M)    SX446     3
# ZMB0 (M)     SX86     1
#
# [2137 rows x 2 columns]

# %% [markdown]
# ## Values in these dataframes tend to be objects:

# %% [markdown]
# ### For instance, index contains Person:

# %%
train.phones_to_usages_df.index[3]

# %% [markdown]
# ### Sentences are objects as well:

# %%
train.sentences_by_phone_df('aa').sentence[0]

# %% [markdown]
# # Region

# %%
train.regions
# Out:
# {'DR1': <timit_utils.core.Region at 0x1135749b0>,
#  'DR2': <timit_utils.core.Region at 0x113574a20>,
#  'DR3': <timit_utils.core.Region at 0x113574a58>,
#  'DR4': <timit_utils.core.Region at 0x113574a90>,
#  'DR5': <timit_utils.core.Region at 0x113574ac8>,
#  'DR6': <timit_utils.core.Region at 0x113574b00>,
#  'DR7': <timit_utils.core.Region at 0x113574b38>,
#  'DR8': <timit_utils.core.Region at 0x113574b70>}

# %%
r0 = train.region_by_index(1)
r0

# %%
r0.phones_to_usages_df
# Out:
#           aa  ae  ah  ao  aw  ax  ax-h  axr  ay   b ...  tcl  th  uh  uw  ux  \
# AEM0 (F)   6  12   2   9   1   6     0    6   4   6 ...   10   5   2   3   5
# AJW0 (F)   4  11   7   9   2   7     1   11   4   5 ...   13   3   3   0   1
# ARC0 (M)  10   9   6   5   1  10     2    7   4   4 ...   11   1   1   0   5
# BJV0 (M)   7   6   4   8   1  10     3    5   6   3 ...    9   4   0   1   3
# CAJ0 (F)   9  11   3   5   0   8     1   10   3   8 ...   15   0   2   3   4
# CEW0 (M)  10   6   5   5   3  15     1    7   5   5 ...   15   1   0   4   2
# CMM0 (F)   7  10   4   7   2   9     0    8   2   4 ...   13   5   1   1   1
# CTM0 (M)   7   8   7   4   3   8     1    5   5   3 ...   12   1   2   2   3
# CYL0 (F)   5   7   5   3   3   5     1   11   6   2 ...   22   0   1   3   5
# RJM0 (M)  3   6  5  11   0
# RJM1 (M)  9   5  3   9   0
# RJT0 (M)  4   6  2   9   0
# RLJ0 (M)  4   7  6   8   1
# RLL0 (F)  1   8  2   4   0
# RLR0 (M)  5   8  4   4   0
# RMS0 (M)  3   8  2   4   0
# SAT0 (M)  2   7  2  10   0
# SCN0 (F)  1   6  1   8   1
# SKL0 (F)  3   7  4   6   0
# SRH0 (F)  3   7  2   6   0
# TAT1 (M)  1   7  5   6   0
# TBC0 (M)  0   5  2   5   0
# TDB0 (M)  7  10  2   7   0
# TJG0 (M)  6   8  2   4   0
# TMG0 (F)  6   3  3  11   0
# WSB0 (M)  7  10  4  10   0
# ZMB0 (M)  6   8  5   9   0
#
# [76 rows x 60 columns]

# %% [markdown]
# # Person

# %% [markdown]
# ## You can get Person from Region or SubCorpus:

# %%
p0 = train.person_by_index(0) 
p0.name
# Out:
# 'ABC0'

# %%
rp0 = train.region_by_index(0).person_by_index(0)
rp0, rp0.name
# Out:
# (<timit_utils.core.Person at 0x11358a240>, 'CJF0')

# %% [markdown]
# # Sentence

# %% [markdown]
# ## You can get Sentences from Person, or Region or SubCorpus DataFrames

# %%
p0.sentences
# Out:
# {'SA1': <timit_utils.core.Sentence at 0x21fb9e7b518>,
#  'SA2': <timit_utils.core.Sentence at 0x21fb9e7b5c0>,
#  'SI1620': <timit_utils.core.Sentence at 0x21fb9e7b400>,
#  'SI2041': <timit_utils.core.Sentence at 0x21fb9e7ba20>,
#  'SI781': <timit_utils.core.Sentence at 0x21fb9e7b358>,
#  'SX151': <timit_utils.core.Sentence at 0x21fb9e7b2b0>,
#  'SX241': <timit_utils.core.Sentence at 0x21fb9e7b320>,
#  'SX331': <timit_utils.core.Sentence at 0x21fb9e7bac8>,
#  'SX421': <timit_utils.core.Sentence at 0x21fb9e7b7f0>,
#  'SX61': <timit_utils.core.Sentence at 0x21fb9e7b5f8>}

# %%
s0 = p0.sentence_by_index(0)
s0, s0.name
# Out:
# (<timit_utils.core.Sentence at 0x21fb9e7b518>, 'SA1')

# %%
s0 = train.sentences_by_phone_df('aa').sentence[0]
s0, s0.name
# Out:
# (<timit_utils.core.Sentence at 0x21fb9e7b518>, 'SA1')

# %% [markdown]
# ## Sentences contain raw audio:

# %%
s0.raw_audio
# Out:
# array([ 0.00036621,  0.00015259,  0.        , ..., -0.00021362,
#        -0.00042725, -0.00012207])

# %%
s0.sample_rate
# Out:
# 16000

# %% [markdown]
# ## We can get dataframes that contain transcriptions of words and phonemes:

# %%
s0.words_df
# Out:
#         start    end
# she      2560   4678
# had      4678   7000
# your     7000   8791
# dark     8791  12519
# suit    12519  16680
# in      16680  18560
# greasy  18560  24062
# wash    24062  28400
# water   29280  32626
# all     32626  34757
# year    34757  38920

# %%
s0.phones_df
# Out:
#       start    end
# sh     2560   4130
# iy     4130   4678
# hv     4678   5389
# ae     5389   7000
# zh     7000   8313
# ax-h   8313   8791
# dcl    8791   9170
# d      9170   9660
# aa     9660  10973
# r     10973  11720
# kcl   11720  12519
# s     12519  14470
# ux    14470  16280
# dx    16280  16680
# ix    16680  17528
# n     17528  18560
# gcl   18560  19540
# g     19540  20070
# r     20070  20596
# iy    20596  21650
# s     21650  23160
# ix    23160  24062
# w     24062  25399
# aa    25399  27530
# sh    27530  28400
# epi   28400  29280
# w     29280  29906
# uh    29906  30754
# dx    30754  31160
# axr   31160  32626
# ao    32626  33963
# l     33963  34757
# y     34757  36200
# ih    36200  37514
# axr   37514  38920

# %% [markdown]
# ## And Counters thereof...

# %%
s0.word_counts
# Out:
# Counter({'all': 1,
#          'dark': 1,
#          'greasy': 1,
#          'had': 1,
#          'in': 1,
#          'she': 1,
#          'suit': 1,
#          'wash': 1,
#          'water': 1,
#          'year': 1,
#          'your': 1})

# %%
s0.phone_counts
# Out:
# Counter({'aa': 2,
#          'ae': 1,
#          'ao': 1,
#          'ax-h': 1,
#          'axr': 2,
#          'd': 1,
#          'dcl': 1,
#          'dx': 2,
#          'epi': 1,
#          'g': 1,
#          'gcl': 1,
#          'hv': 1,
#          'ih': 1,
#          'ix': 2,
#          'iy': 2,
#          'kcl': 1,
#          'l': 1,
#          'n': 1,
#          'r': 2,
#          's': 2,
#          'sh': 2,
#          'uh': 1,
#          'ux': 1,
#          'w': 2,
#          'y': 1,
#          'zh': 1})

# %%
features = au.audio_features(s0.raw_audio, s0.sample_rate)
features.shape
# Out:
# (2690, 66)

# %% [markdown]
# # Audio feature extraction

# %% [markdown]
# ## Turn it into features of all sorts: [mel energies + mel filterbank + log mel filterbank + mfcc signal]

# %%
gained_padded_audio = au.audio_gained(au.audio_zero_padded(8000, s0.raw_audio, 8000), 1.0)
audio_features = au.audio_features(gained_padded_audio, s0.sample_rate)
sampled_audio = au.resampled_audio(s0.raw_audio, 
                       sample_rate = s0.sample_rate, 
                       pad = 8000, 
                       to_sample_rate = 1000)
print(gained_padded_audio.shape, sampled_audio.shape, audio_features.shape)
# Out:
# (59418,) (3708,) (3690, 66)

# %% [markdown]
# ## Get down-sampled words and phoneme sequences

# %%
sentence_phones_input = au.resampled_phones_df(s0.phones_df, s0.sample_rate, left_pad=8000)
sentence_words_input = au.resampled_phones_df(s0.words_df, s0.sample_rate, left_pad=8000)

# %% [markdown]
# ## Draw everything
# * Raw audio
# * Raw word transcriptions
# * Raw phoneme transcriptions
# * Downsampled audio
# * Downsampled word transcriptions
# * Downsampled phoneme transcriptions
# * Mel features

# %%
du.DrawVerticalPanels([du.AudioPanel(s0.raw_audio, show_x_axis=True), 
                       du.WordsPanel(s0.words_df, s0.raw_audio.shape[0], show_x_axis=True),
                       du.PhonesPanel(s0.phones_df, s0.raw_audio.shape[0]),
                       du.AudioPanel(sampled_audio, show_x_axis=True),
                       du.WordsPanel(sentence_words_input, sampled_audio.shape[0], show_x_axis=True),
                       du.PhonesPanel(sentence_phones_input, sampled_audio.shape[0]),
                       du.SignalsPanel(audio_features)
                      ])

# %%
# Out:
# array([[2075.26335213, 2075.26335213, 2075.26335213, ..., 2075.26335213,
#         2075.26335213, 2075.26335213],
#        [2075.26335213, 2075.26335213, 2075.26335213, ..., 2075.26335213,
#         2075.26335213, 2075.26335213],
#        [2075.26335213, 2075.26335213, 2075.26335213, ..., 2075.26335213,
#         2075.26335213, 2075.26335213],
#        ...,
#        [2075.26335213, 2075.26335213, 2075.26335213, ..., 2075.26335213,
#         2075.26335213, 2075.26335213],
#        [2075.26335213, 2075.26335213, 2075.26335213, ..., 2075.26335213,
#         2075.26335213, 2075.26335213],
#        [2075.26335213, 2075.26335213, 2075.26335213, ..., 2075.26335213,
#         2075.26335213, 2075.26335213]])

# %%
# Out:
# 1.291892973709352e-07
