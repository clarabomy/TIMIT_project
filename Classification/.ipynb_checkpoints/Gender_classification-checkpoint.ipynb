# %% [markdown]
# # Classification by age on the TIMIT dataset

# %% [markdown]
# In this notebook, we will try to extract the MFCC features from the audio files of the TIMIT dataset in order to predict the gender of speakers.

# %% [markdown]
# # Importing useful libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import librosa as lr
import matplotlib.pyplot as plt
import pylab, librosa.display, utils #utils contains all the functions we have created or inspired from

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
# Out:
# utils.py correctly charged

# %% [markdown]
# # Recovery of data as dataframes

# %% [markdown]
# We have retrieved the data contained in the files train.csv and test.csv. We load this data as dataframes with the pandas library.

# %%
df_train = pd.read_csv("train.csv", "|")
df_test = pd.read_csv("test.csv", "|")

# %% [markdown]
# We verify that the dataframes have been correctly loaded.

# %%
df_train.head()
# Out:
#   soundName personName TRN/TST                        soundPath  \
# 0       sa1       ABC0     TRN    TIMIT/TRAIN/DR6/MABC0/SA1.wav
# 1       sa2       ABC0     TRN    TIMIT/TRAIN/DR6/MABC0/SA2.wav
# 2     sx331       ABC0     TRN  TIMIT/TRAIN/DR6/MABC0/SX331.wav
# 3      sx61       ABC0     TRN   TIMIT/TRAIN/DR6/MABC0/SX61.wav
# 4     sx241       ABC0     TRN  TIMIT/TRAIN/DR6/MABC0/SX241.wav
#
#                            wrdPath                          phnPath  \
# 0    TIMIT/TRAIN/DR6/MABC0/SA1.wrd    TIMIT/TRAIN/DR6/MABC0/SA1.phn
# 1    TIMIT/TRAIN/DR6/MABC0/SA2.wrd    TIMIT/TRAIN/DR6/MABC0/SA2.phn
# 2  TIMIT/TRAIN/DR6/MABC0/SX331.wrd  TIMIT/TRAIN/DR6/MABC0/SX331.phn
# 3   TIMIT/TRAIN/DR6/MABC0/SX61.wrd   TIMIT/TRAIN/DR6/MABC0/SX61.phn
# 4  TIMIT/TRAIN/DR6/MABC0/SX241.wrd  TIMIT/TRAIN/DR6/MABC0/SX241.phn
#
#                            txtPath gender         region  age recordDate  \
# 0    TIMIT/TRAIN/DR6/MABC0/SA1.txt      M  New York City   25   03/03/86
# 1    TIMIT/TRAIN/DR6/MABC0/SA2.txt      M  New York City   25   03/03/86
# 2  TIMIT/TRAIN/DR6/MABC0/SX331.txt      M  New York City   25   03/03/86
# 3   TIMIT/TRAIN/DR6/MABC0/SX61.txt      M  New York City   25   03/03/86
# 4  TIMIT/TRAIN/DR6/MABC0/SX241.txt      M  New York City   25   03/03/86
#
#   birthDate  height race education  \
# 0  06/17/60  180.34  WHT       BS
# 1  06/17/60  180.34  WHT       BS
# 2  06/17/60  180.34  WHT       BS
# 3  06/17/60  180.34  WHT       BS
# 4  06/17/60  180.34  WHT       BS
#
#                                                  phn  \
# 0  h# sh iy hv ae zh ax-h dcl d aa r kcl s ux dx ...
# 1  h# d ow nx ae s kcl m ix dx ix kcl k eh r ih i...
# 2  h# dh ix bcl b ih gcl d ao gcl l ah v dcl t ax...
# 3  h# ch aa kcl k l ix q en r ow z ix z n eh v ax...
# 4  h# dh hv ao w ey ow pcl p ix n z ix n ux ix hh...
#
#                                             prompt  start    end
# 0  She had your dark suit in greasy wash water all      0  43418
# 1           Don't ask me to carry an oily rag like      0  35840
# 2         The big dog loved to chew on the old rag      0  39322
# 3     Chocolate and roses never fail as a romantic      0  39936
# 4                    The hallway opens into a huge      0  31949

# %% [markdown]
# # Data visualization

# %% [markdown]
# Then, we check that the data to be classified is correctly balanced.

# %%
print("Shape of training data : ", df_train.shape)
print("Shape of testing data  : ", df_test.shape)
# Out:
# Shape of training data :  (4620, 19)
# Shape of testing data  :  (1680, 19)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4620 entries, 0 to 4619
# Data columns (total 19 columns):
# soundName     4620 non-null object
# personName    4620 non-null object
# TRN/TST       4620 non-null object
# soundPath     4620 non-null object
# wrdPath       4620 non-null object
# phnPath       4620 non-null object
# txtPath       4620 non-null object
# gender        4620 non-null object
# region        4620 non-null object
# age           4620 non-null int64
# recordDate    4620 non-null object
# birthDate     4620 non-null object
# height        4620 non-null float64
# race          4620 non-null object
# education     4620 non-null object
# phn           4620 non-null object
# prompt        4620 non-null object
# start         4620 non-null int64
# end           4620 non-null int64
# dtypes: float64(1), int64(3), object(15)
# memory usage: 685.9+ KB

# %% [markdown]
# We delete all columns of dataframes that are not useful for classification.

# %%
df_train = df_train.drop(['phn','personName','soundName','txtPath','phnPath','wrdPath','TRN/TST','region','age','recordDate','birthDate','height','race','education','prompt','start','end'], axis = 1)
df_test = df_test.drop(['phn', 'personName','soundName','txtPath','phnPath','wrdPath','TRN/TST','region','age','recordDate','birthDate','height','race','education','prompt','start','end'], axis = 1)

# %% [markdown]
# We map the labels as integers so that they can be read by our models. We will assign the value '0' to the male speakers class and the value '1' to the female speakers class.

# %%
df_train['map_gender'] = df_train.gender.map({'M':0, 'F':1})
df_test['map_gender'] = df_test.gender.map({'M':0, 'F':1})

# %%
df_train.head()
# Out:
#                          soundPath gender  map_gender
# 0    TIMIT/TRAIN/DR6/MABC0/SA1.wav      M           0
# 1    TIMIT/TRAIN/DR6/MABC0/SA2.wav      M           0
# 2  TIMIT/TRAIN/DR6/MABC0/SX331.wav      M           0
# 3   TIMIT/TRAIN/DR6/MABC0/SX61.wav      M           0
# 4  TIMIT/TRAIN/DR6/MABC0/SX241.wav      M           0

# %%
df_test.head()
# Out:
#                         soundPath gender  map_gender
# 0    TIMIT/TEST/DR2/MABW0/SA1.wav      M           0
# 1    TIMIT/TEST/DR2/MABW0/SA2.wav      M           0
# 2  TIMIT/TEST/DR2/MABW0/SX134.wav      M           0
# 3  TIMIT/TEST/DR2/MABW0/SX314.wav      M           0
# 4   TIMIT/TEST/DR2/MABW0/SX44.wav      M           0

# %% [markdown]
# We verify that the training and test data are correctly balanced using graphs.

# %%
type = df_train.map_gender.value_counts()
labels = (np.array(type.index))
sizes = (np.array((type / type.sum())*100))
colors = ['grey', 'orange']
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.title("Percentage distribution of the genders in the train dataset")
plt.show()

df_train.map_gender.value_counts()
# Out:
# 0    3260
# 1    1360
# Name: map_gender, dtype: int64

# %%
type = df_test.map_gender.value_counts()
labels = (np.array(type.index))
sizes = (np.array((type / type.sum())*100))
colors = ['grey', 'orange']
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.title("Percentage distribution of the genders in the test dataset")
plt.show()

df_test.map_gender.value_counts()
# Out:
# 0    1120
# 1     560
# Name: map_gender, dtype: int64

# %% [markdown]
# Here, we clearly see that the data are not balanced - this could be detrimental to learning our models. We will therefore randomly delete data to rebalance them.

# %% [markdown]
# # Undersampling

# %% [markdown]
# We keep the 50/50 ratio of male and female speakers in each set.

# %%
df_train = utils.undersample(df_train, 'map_gender', 1)
print("Train")
print(df_train.map_gender.value_counts())
print("\n")

print("Test")
df_test = utils.undersample(df_test, 'map_gender', 1)
print(df_test.map_gender.value_counts())
# Out:
# Train
# 1    1360
# 0    1360
# Name: map_gender, dtype: int64
#
#
# Test
# 1    560
# 0    560
# Name: map_gender, dtype: int64

# %% [markdown]
# # Extracting audio files

# %% [markdown]
# We recover all the paths of the audio files in order to extract the MFCCs of each audio file to create our training and testing data. MFCCs are computed using the librosa library.

# %%
train_audio_list = df_train.soundPath.tolist()
test_audio_list = df_test.soundPath.tolist()

# %%
train_temp_features = []
test_temp_features = []

for elt in train_audio_list:
    train_temp_features.append(utils.extract_features(elt))

for elt in test_audio_list:
    test_temp_features.append(utils.extract_features(elt))

# %% [markdown]
# # Preparation of train and test data

# %%
X_train = np.array(train_temp_features)
y_train = np.array(df_train.map_gender.tolist())
X_test = np.array(test_temp_features)
y_test = np.array(df_test.map_gender.tolist())

# %% [markdown]
# # Machine Learning

# %% [markdown]
# We will here experiment with different classifiers and assess their performances.

# %% [markdown]
# ### Gaussian Naive Bayes Classifier

# %% [markdown]
# The Gaussian Naive Bayes classifier makes the assumption that the features are independant and that each feature is normally distributed. It is a simple and fast classifier.

# %%
from sklearn.naive_bayes import GaussianNB

clf = GaussianNB()
clf.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# Comparing the predicted values and the actual values, we have several possibilities:
# * True positives (VP or TP): we predict "yes" and the expected value is "yes"
# * True negatives (VN or TN): one predicts "no" and the expected value is "no"
# * False positives (FP): we predict "yes" and the expected value is "no"
# * False negatives (FN): one predicts "no" and the expected value is "yes"
#
# The confusion matrix makes it possible to count the number of TP, TN, FP, FN.
#
#
# Then, we measure the accuracy of the model - number of times the algorithm has made a good prediction (in percentage). Nevertheless, this measure may be distorted in some cases, so we will use other estimators:
#
# * the precision is the number of correct positive predictions on the total number of positive predictions: precision = VP / (VP + FP)
# * the recall is the number of positive predictions about the actual number of "yes": recall = VP (VP + FN)
# * the F1 score is the weighted average of accuracy and sensitivity: f1-score = 2xprecisionxrecall / (precision + recall)

# %%
utils.test_gender_classifier(clf, X_test, y_test)
# Out:
# Test accuracy :  0.9571428571428572
#
# 13 males classified as females out of 560, 2.321 %
# 35 females classified as males out of 560, 6.250 %
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       560
#            1       0.98      0.94      0.96       560
#
#    micro avg       0.96      0.96      0.96      1120
#    macro avg       0.96      0.96      0.96      1120
# weighted avg       0.96      0.96      0.96      1120

# %%
utils.plot_learning_curve(clf, X_train, y_train)
# Out:
# d:\program files\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
utils.plot_roc_curve(clf, X_test, y_test)

# %% [markdown]
# ### XGBoost Classifier

# %% [markdown]
# XGBoost is one of the most popular machine learning algorithm these days : it is well known to provide better solutions than other machine learning algorithms.

# %%
from xgboost import XGBClassifier 

xgb = XGBClassifier()
xgb.fit(X_train,y_train)
utils.test_gender_classifier(xgb, X_test, y_test)
# Out:
# Test accuracy :  0.9723214285714286
#
# 6 males classified as females out of 560, 1.071 %
# 25 females classified as males out of 560, 4.464 %
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       560
#            1       0.99      0.96      0.97       560
#
#    micro avg       0.97      0.97      0.97      1120
#    macro avg       0.97      0.97      0.97      1120
# weighted avg       0.97      0.97      0.97      1120

# %%
utils.plot_learning_curve(xgb, X_train, y_train)
# Out:
# d:\program files\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
utils.plot_roc_curve(xgb, X_test, y_test)

# %% [markdown]
# ### DecisionTree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt_clf = DecisionTreeClassifier(random_state = 0)
dt_clf.fit(X_train, y_train)
utils.test_gender_classifier(dt_clf, X_test, y_test)
# Out:
# Test accuracy :  0.9598214285714286
#
# 19 males classified as females out of 560, 3.393 %
# 26 females classified as males out of 560, 4.643 %
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       560
#            1       0.97      0.95      0.96       560
#
#    micro avg       0.96      0.96      0.96      1120
#    macro avg       0.96      0.96      0.96      1120
# weighted avg       0.96      0.96      0.96      1120

# %%
utils.plot_learning_curve(dt_clf, X_test, y_test)
# Out:
# d:\program files\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
utils.plot_roc_curve(dt_clf, X_test, y_test)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(X_train,y_train)
utils.test_gender_classifier(lr, X_test, y_test)
# Out:
# Test accuracy :  0.9589285714285715
#
# 9 males classified as females out of 560, 1.607 %
# 37 females classified as males out of 560, 6.607 %
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       560
#            1       0.98      0.93      0.96       560
#
#    micro avg       0.96      0.96      0.96      1120
#    macro avg       0.96      0.96      0.96      1120
# weighted avg       0.96      0.96      0.96      1120
# d:\program files\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
utils.plot_learning_curve(lr, X_train, y_train)
# Out:
# d:\program files\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
utils.plot_roc_curve(lr, X_test, y_test)

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(X_train, y_train)
utils.test_gender_classifier(rf, X_test, y_test)
# Out:
# Test accuracy :  0.9723214285714286
#
# 8 males classified as females out of 560, 1.429 %
# 23 females classified as males out of 560, 4.107 %
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       560
#            1       0.99      0.96      0.97       560
#
#    micro avg       0.97      0.97      0.97      1120
#    macro avg       0.97      0.97      0.97      1120
# weighted avg       0.97      0.97      0.97      1120
# d:\program files\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
utils.plot_learning_curve(rf, X_train, y_train)
# Out:
# d:\program files\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
utils.plot_roc_curve(rf, X_test, y_test)

# %% [markdown]
# ### GradientBoosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier()
gb.fit(X_train,y_train)
utils.test_gender_classifier(gb, X_test, y_test)
# Out:
# Test accuracy :  0.9741071428571428
#
# 6 males classified as females out of 560, 1.071 %
# 23 females classified as males out of 560, 4.107 %
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       560
#            1       0.99      0.96      0.97       560
#
#    micro avg       0.97      0.97      0.97      1120
#    macro avg       0.97      0.97      0.97      1120
# weighted avg       0.97      0.97      0.97      1120

# %%
utils.plot_learning_curve(gb, X_train, y_train)
# Out:
# d:\program files\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
utils.plot_roc_curve(gb, X_test, y_test)

# %% [markdown]
# # Deep Learning

# %% [markdown]
# Here we will experiment with a simple neural network written in Keras. Our CNN is composed of fully connected layers and a sigmoid for binary classification.
#
# On average, the test accuracy is 95-97%

# %%
from keras import models
from keras import layers
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

model = models.Sequential()
model.add(layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From d:\program files\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From d:\program files\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %% [markdown]
# The structure of the neural network used is the following :

# %%
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               10496
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 51,713
# Trainable params: 51,713
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
classifier = model.fit(X_train, y_train, batch_size=32, epochs=9, validation_data=(X_test, y_test))
# Out:
# WARNING:tensorflow:From d:\program files\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 2720 samples, validate on 1120 samples
# Epoch 1/9
# 2720/2720 [==============================] - 0s 170us/step - loss: 2.4874 - acc: 0.7632 - val_loss: 0.0899 - val_acc: 0.9723
# Epoch 2/9
# 2720/2720 [==============================] - 0s 63us/step - loss: 0.1016 - acc: 0.9699 - val_loss: 0.0807 - val_acc: 0.9732
# Epoch 3/9
# 2720/2720 [==============================] - 0s 73us/step - loss: 0.0798 - acc: 0.9772 - val_loss: 0.0788 - val_acc: 0.9723
# Epoch 4/9
# 2720/2720 [==============================] - 0s 90us/step - loss: 0.0760 - acc: 0.9765 - val_loss: 0.1068 - val_acc: 0.9696
# Epoch 5/9
# 2720/2720 [==============================] - 0s 72us/step - loss: 0.0745 - acc: 0.9772 - val_loss: 0.0698 - val_acc: 0.9732
# Epoch 6/9
# 2720/2720 [==============================] - 0s 65us/step - loss: 0.0674 - acc: 0.9776 - val_loss: 0.0782 - val_acc: 0.9750
# Epoch 7/9
# 2720/2720 [==============================] - 0s 60us/step - loss: 0.0502 - acc: 0.9824 - val_loss: 0.0713 - val_acc: 0.9768
# Epoch 8/9
# 2720/2720 [==============================] - 0s 62us/step - loss: 0.0412 - acc: 0.9868 - val_loss: 0.0726 - val_acc: 0.9750
# Epoch 9/9
# 2720/2720 [==============================] - 0s 62us/step - loss: 0.0474 - acc: 0.9846 - val_loss: 0.1577 - val_acc: 0.9661

# %%
utils.model_curves(classifier)

# %%
classifier = model.save('gender_classifier.h5')

# %%
scores = model.evaluate(X_test, y_test)
print("Score : %.2f%%" % (scores[1]*100))
# Out:
# 1120/1120 [==============================] - 0s 32us/step
# Score : 96.61%

# %% [markdown]
# ## Prediction

# %% [markdown]
# We load an audio file from the test dataset at random and we check the prediction of the neural network.

# %%
y_pred = model.predict(X_test)

# %%
from scipy.io import wavfile as wav
import IPython.display as ipd
import random

labels = ["male","female"]
speaker_genders = df_test.gender.tolist()
n_test = X_test.shape[0]
ir = random.randint(0,n_test)

print("Filename :", test_audio_list[ir])
print("Model prediction :", labels[int(round(y_pred[ir][0]))], "-", y_pred[ir][0])
print("Real gender of the speaker :", speaker_genders[ir])

ipd.Audio(test_audio_list[ir])
# Out:
# Filename : TIMIT/TEST/DR1/FDAC1/SI1474.wav
# Model prediction : female - 0.90082234
# Real gender of the speaker : F
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Thus, the scores obtained are of the order of 96% - which is a very good result.
